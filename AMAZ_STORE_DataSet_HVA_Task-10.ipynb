# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn

# %%
amaz = pd.read_csv("/home/prince/Downloads/amazon_books.csv")
amaz
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
amaz.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
amaz.tail()
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %%
amaz.max()
# Out:
# Name           You Are a Badass: How to Stop Doubting Your Gr...
# Author                                              Zhi Gang Sha
# User Rating                                                  4.9
# Reviews                                                    87841
# Price                                                        105
# Year                                                        2019
# Genre                                                Non Fiction
# dtype: object

# %%
amaz.min()
# Out:
# Name           10-Day Green Smoothie Cleanse
# Author                      Abraham Verghese
# User Rating                              3.3
# Reviews                                   37
# Price                                      0
# Year                                    2009
# Genre                                Fiction
# dtype: object

# %%
amaz.mean()
# Out:
# User Rating        4.618364
# Reviews        11953.281818
# Price             13.100000
# Year            2014.000000
# dtype: float64

# %%
amaz.mode()
# Out:
#                                                  Name       Author  \
# 0   Publication Manual of the American Psychologic...  Jeff Kinney
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7                                                 NaN          NaN
# 8                                                 NaN          NaN
# 9                                                 NaN          NaN
# 10                                                NaN          NaN
#
#     User Rating  Reviews  Price  Year        Genre
# 0           4.8   8580.0    8.0  2009  Non Fiction
# 1           NaN      NaN    NaN  2010          NaN
# ...

# %%
amaz.std()
# Out:
# User Rating        0.226980
# Reviews        11731.132017
# Price             10.842262
# Year               3.165156
# dtype: float64

# %%
amaz.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
amaz.shape
# Out:
# (550, 7)

# %%
amaz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 23.7+ KB

# %%
amaz.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %%
amaz.size
# Out:
# 3850

# %%
amaz.loc[2:3]
# Out:
#                                       Name              Author  User Rating  \
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
# 3                   1984 (Signet Classics)       George Orwell          4.7
#
#    Reviews  Price  Year        Genre
# 2    18979     15  2018  Non Fiction
# 3    21424      6  2017      Fiction

# %%
s1 =amaz[['Name', 'Genre']]
s1
# Out:
#                                                   Name        Genre
# 0                        10-Day Green Smoothie Cleanse  Non Fiction
# 1                                    11/22/63: A Novel      Fiction
# 2              12 Rules for Life: An Antidote to Chaos  Non Fiction
# 3                               1984 (Signet Classics)      Fiction
# 4    5,000 Awesome Facts (About Everything!) (Natio...  Non Fiction
# ..                                                 ...          ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)      Fiction
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Non Fiction
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Non Fiction
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Non Fiction
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Non Fiction
#
# [550 rows x 2 columns]

# %%
sn.countplot(data=amaz,x="Genre", palette = "Set2")
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='count'>

# %%
s1.value_counts()
# Out:
# Name                                                                                          Genre
# Publication Manual of the American Psychological Association, 6th Edition                     Non Fiction    10
# StrengthsFinder 2.0                                                                           Non Fiction     9
# Oh, the Places You'll Go!                                                                     Fiction         8
# The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change                  Non Fiction     7
# The Very Hungry Caterpillar                                                                   Fiction         7
#                                                                                                              ..
# Sycamore Row (Jake Brigance)                                                                  Fiction         1
# ...

# %%
plt.figure(figsize=(4,2))
sn.set(style="darkgrid")
ax = sn.countplot(x="Genre", data=amaz, palette="Set3", order=amaz['Genre'].value_counts().index[0:10])
#for i in ax.container:
    #plt.show(i)

# %%
g1 = amaz['Name'].value_counts()
g1
# Out:
# Publication Manual of the American Psychological Association, 6th Edition       10
# StrengthsFinder 2.0                                                              9
# Oh, the Places You'll Go!                                                        8
# The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change     7
# The Very Hungry Caterpillar                                                      7
#                                                                                 ..
# A Wrinkle in Time (Time Quintet)                                                 1
# Dog Days (Diary of a Wimpy Kid, Book 4) (Volume 4)                               1
# A Dance with Dragons (A Song of Ice and Fire)                                    1
# The Constitution of the United States                                            1
# And the Mountains Echoed                                                         1
# Name: Name, Length: 351, dtype: int64

# %%
plt.figure(figsize=(6,4))
sn.set(style="darkgrid")
ax = sn.countplot(x="Year", data=amaz, palette="Set3", order=amaz['Year'].value_counts().index[0:200])
#for i in ax.container:
    #plt.show(i)

# %%
count_year = amaz['Year'].value_counts().reset_index()
count_year.columns = ['Release Year', 'No of Movies']
count_year
# Out:
#     Release Year  No of Movies
# 0           2019            50
# 1           2018            50
# 2           2017            50
# 3           2016            50
# 4           2015            50
# 5           2014            50
# 6           2013            50
# 7           2012            50
# 8           2011            50
# 9           2010            50
# 10          2009            50

# %%
count_year = count_year.sort_values(by='Release Year')
plt.figure(figsize=(10, 6))
x = sn.barplot(x='Release Year', y='No of Movies', data=count_year, palette='viridis')
for p in x.patches:
    x.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=10)

# %%
amaz.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
g1 = amaz[['User Rating']].mean()
print(g1)
# Out:
# User Rating    4.618364
# dtype: float64

# %%
amaz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 23.7+ KB

# %%
amaz.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
amaz.describe(include='O')
# Out:
#                                                      Name       Author  \
# count                                                 550          550
# unique                                                351          248
# top     Publication Manual of the American Psychologic...  Jeff Kinney
# freq                                                   10           12
#
#               Genre
# count           550
# unique            2
# top     Non Fiction
# freq            310

# %%
avg_rating_by_author = amaz.groupby('Author')['User Rating'].mean().reset_index()
avg_rating_by_author
# Out:
#                          Author  User Rating
# 0              Abraham Verghese     4.600000
# 1                Adam Gasiewski     4.400000
# 2                 Adam Mansbach     4.800000
# 3                     Adir Levy     4.800000
# 4    Admiral William H. McRaven     4.700000
# ..                          ...          ...
# 243             Walter Isaacson     4.566667
# 244               William Davis     4.400000
# 245            William P. Young     4.600000
# 246            Wizards RPG Team     4.800000
# 247                Zhi Gang Sha     4.600000
#
# [248 rows x 2 columns]

# %%
avg_rating_by_author = amaz.groupby('Author')['User Rating'].mean().reset_index()
# Getting the top 5 authors with the highest average rating
top5_authors = avg_rating_by_author.nlargest(5, 'User Rating')
print(top5_authors)
# Out:
#                     Author  User Rating
# 8           Alice Schertle          4.9
# 26         Bill Martin Jr.          4.9
# 41             Chip Gaines          4.9
# 82   Emily Winfield Martin          4.9
# 123             Jill Twiss          4.9

# %%
author_book_counts = amaz['Author'].value_counts()

# %%
author_book_counts
# Out:
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
#                                       ..
# Dave Ramsey                            1
# Jon Stewart                            1
# Jordan B. Peterson                     1
# Adir Levy                              1
# Mary Ann Shaffer                       1
# Name: Author, Length: 248, dtype: int64

# %%
authors_with_one_book = author_book_counts[author_book_counts == 1].index

# %%
authors_with_one_book
# Out:
# Index(['Bob Woodward', 'Hillary Rodham Clinton', 'Heidi Murkoff',
#        'Allie Brosh', 'Brian Kilmeade', 'M Prefontaine', 'Paula McLain',
#        'Madeleine L'Engle', 'Bruce Springsteen', 'Howard Stern',
#        ...
#        'Hopscotch Girls', 'David Grann', 'W. Cleon Skousen',
#        'National Geographic Kids', 'Larry Schweikart', 'Dave Ramsey',
#        'Jon Stewart', 'Jordan B. Peterson', 'Adir Levy', 'Mary Ann Shaffer'],
#       dtype='object', length=130)

# %%
author_book_counts = amaz['Author'].value_counts()
# Filtering authors who have published exactly one book
authors_with_one_book = author_book_counts[author_book_counts == 1].index
# Creating a new DataFrame with authors who have published exactly one book
result_df = amaz[amaz['Author'].isin(authors_with_one_book)]
result_df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 7                       A Gentleman in Moscow: A Novel
# ..                                                 ...
# 535                          Where the Wild Things Are
# 536  Whose Boat Is This Boat?: Comments That Don't ...
# 537  Wild: From Lost to Found on the Pacific Crest ...
# 538  Winter of the World: Book Two of the Century T...
# 539  Women Food and God: An Unexpected Path to Almo...
#
#                                Author  User Rating  Reviews  Price  Year  \
# 0                            JJ Smith          4.7    17350      8  2016
# 2                  Jordan B. Peterson          4.7    18979     15  2018
# 3                       George Orwell          4.7    21424      6  2017
# ...

# %%
result_df.size
# Out:
# 910

# %%
result_df.count()
# Out:
# Name           130
# Author         130
# User Rating    130
# Reviews        130
# Price          130
# Year           130
# Genre          130
# dtype: int64

# %%
len(result_df)
# Out:
# 130

# %%
author_book_counts = amaz['Author'].value_counts()
authors_with_5books = author_book_counts[author_book_counts >5]
authors_with_5books
# Out:
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
# Dr. Seuss                              9
# Gallup                                 9
# Rob Elliott                            8
# Stephenie Meyer                        7
# Bill O'Reilly                          7
# Dav Pilkey                             7
# Eric Carle                             7
# Stephen R. Covey                       7
# Don Miguel Ruiz                        6
# The College Board                      6
# J.K. Rowling                           6
# Harper Lee                             6
# Stieg Larsson                          6
# Sarah Young                            6
# E L James                              6
# Name: Author, dtype: int64

# %%
authors_with_5books.count()
# Out:
# 20

# %%
author_book_counts = amaz['Author'].value_counts()
authors_with_5books_above  = author_book_counts[author_book_counts >=5]
authors_with_5books_above
# Out:
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
# Dr. Seuss                              9
# Gallup                                 9
# Rob Elliott                            8
# Stephenie Meyer                        7
# Bill O'Reilly                          7
# Dav Pilkey                             7
# Eric Carle                             7
# Stephen R. Covey                       7
# Don Miguel Ruiz                        6
# The College Board                      6
# J.K. Rowling                           6
# Harper Lee                             6
# Stieg Larsson                          6
# Sarah Young                            6
# E L James                              6
# Giles Andreae                          5
# Patrick Lencioni                       5
# R. J. Palacio                          5
# ...

# %%
authors_with_5books_above.count()
# Out:
# 28

# %%
author_book_counts = amaz['Author'].value_counts()

# Filtering authors who have published min 5 books and above
authors_with_5books_above  = author_book_counts[author_book_counts >5].index
authors_with_5books_above
# Out:
# Index(['Jeff Kinney', 'Gary Chapman', 'Rick Riordan', 'Suzanne Collins',
#        'American Psychological Association', 'Dr. Seuss', 'Gallup',
#        'Rob Elliott', 'Stephenie Meyer', 'Bill O'Reilly', 'Dav Pilkey',
#        'Eric Carle', 'Stephen R. Covey', 'Don Miguel Ruiz',
#        'The College Board', 'J.K. Rowling', 'Harper Lee', 'Stieg Larsson',
#        'Sarah Young', 'E L James'],
#       dtype='object')

# %%
author_book_counts = amaz['Author'].value_counts()

# Filtering authors who have published exactly one book
authors_with_5books_above = author_book_counts[author_book_counts >=5].index

# Creating a new DataFrame with authors who have published exactly one book
result_df = amaz[amaz['Author'].isin(authors_with_5books_above)]
result_df
# Out:
#                                              Name           Author  \
# 38      Breaking Dawn (The Twilight Saga, Book 4)  Stephenie Meyer
# 42     Cabin Fever (Diary of a Wimpy Kid, Book 6)      Jeff Kinney
# 46               Catching Fire (The Hunger Games)  Suzanne Collins
# 47               Catching Fire (The Hunger Games)  Suzanne Collins
# 48               Catching Fire (The Hunger Games)  Suzanne Collins
# ..                                            ...              ...
# 541                                        Wonder    R. J. Palacio
# 542                                        Wonder    R. J. Palacio
# 543                                        Wonder    R. J. Palacio
# 544                                        Wonder    R. J. Palacio
# 545  Wrecking Ball (Diary of a Wimpy Kid Book 14)      Jeff Kinney
#
#      User Rating  Reviews  Price  Year    Genre
# 38           4.6     9769     13  2009  Fiction
# 42           4.8     4505      0  2011  Fiction
# ...

# %%
result_df.count()
# Out:
# Name           198
# Author         198
# User Rating    198
# Reviews        198
# Price          198
# Year           198
# Genre          198
# dtype: int64

# %%
len(result_df)
# Out:
# 198

# %%
result_df.size
# Out:
# 1386

# %%
author_counts = amaz['Name'].value_counts()
author_counts
# Out:
# Publication Manual of the American Psychological Association, 6th Edition       10
# StrengthsFinder 2.0                                                              9
# Oh, the Places You'll Go!                                                        8
# The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change     7
# The Very Hungry Caterpillar                                                      7
#                                                                                 ..
# A Wrinkle in Time (Time Quintet)                                                 1
# Dog Days (Diary of a Wimpy Kid, Book 4) (Volume 4)                               1
# A Dance with Dragons (A Song of Ice and Fire)                                    1
# The Constitution of the United States                                            1
# And the Mountains Echoed                                                         1
# Name: Name, Length: 351, dtype: int64

# %%
author_max_no_book =author_counts.nlargest()
author_max_no_book
# Out:
# Publication Manual of the American Psychological Association, 6th Edition       10
# StrengthsFinder 2.0                                                              9
# Oh, the Places You'll Go!                                                        8
# The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change     7
# The Very Hungry Caterpillar                                                      7
# Name: Name, dtype: int64

# %%
author_book_counts = amaz['Author'].value_counts()
author_book_counts
# Out:
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
#                                       ..
# Dave Ramsey                            1
# Jon Stewart                            1
# Jordan B. Peterson                     1
# Adir Levy                              1
# Mary Ann Shaffer                       1
# Name: Author, Length: 248, dtype: int64

# %%
author_book_counts1 = amaz['Author'].value_counts().nlargest(1)
author_book_counts1
# Out:
# Jeff Kinney    12
# Name: Author, dtype: int64

# %%
author_book_counts2 = amaz['Author'].value_counts().nlargest(1).index
author_book_counts2
# Out:
# Index(['Jeff Kinney'], dtype='object')

# %%
author_book_counts3 = amaz['Author'].value_counts().max()
author_book_counts3
# Out:
# 12

# %%
# Counting the number of books published by each author
author_book_counts = amaz['Author'].value_counts()

# Finding the maximum number of books published by a single author
max_books_count = author_book_counts.max()

# Finding the author(s) who have published the maximum number of books
authors_with_max_books = author_book_counts[author_book_counts == max_books_count].index
authors_with_max_books
# Out:
# Index(['Jeff Kinney'], dtype='object')

# %%
total_review = amaz.groupby(['Genre','Reviews']).sum()
total_review
# Out:
#                      User Rating  Price   Year
# Genre       Reviews
# Fiction     548              4.8      2   2010
#             973              4.7     25   2009
#             978              4.6      0   2014
#             1320             4.6      7   2009
#             1463             4.7     10   2011
# ...                          ...    ...    ...
# Non Fiction 25554           24.0     40  10085
#             26490           13.8     45   6054
#             28729            9.4     30   4037
#             29673           24.0     77  10061
#             61133            9.6     22   4037
#
# [348 rows x 3 columns]

# %%
total_review = amaz.groupby(['Genre','Year'])['Reviews'].sum()
total_review
# Out:
# Genre        Year
# Fiction      2009    156824
#              2010    168185
#              2011    217041
#              2012    417821
#              2013    479684
#              2014    562103
#              2015    403004
#              2016    371702
#              2017    350684
#              2018    266919
#              2019    370143
# Non Fiction  2009     78682
#              2010    105796
#              2011    188000
#              2012    236725
#              2013    175223
#              2014    230894
#              2015    308665
#              2016    338098
#              2017    293736
#              2018    429602
#              2019    424774
# Name: Reviews, dtype: int64

# %%
total_review1 = amaz.groupby(['Genre','Year'])['Reviews'].sum().reset_index()
total_review1
# Out:
#           Genre  Year  Reviews
# 0       Fiction  2009   156824
# 1       Fiction  2010   168185
# 2       Fiction  2011   217041
# 3       Fiction  2012   417821
# 4       Fiction  2013   479684
# 5       Fiction  2014   562103
# 6       Fiction  2015   403004
# 7       Fiction  2016   371702
# 8       Fiction  2017   350684
# 9       Fiction  2018   266919
# 10      Fiction  2019   370143
# 11  Non Fiction  2009    78682
# 12  Non Fiction  2010   105796
# 13  Non Fiction  2011   188000
# 14  Non Fiction  2012   236725
# 15  Non Fiction  2013   175223
# 16  Non Fiction  2014   230894
# 17  Non Fiction  2015   308665
# 18  Non Fiction  2016   338098
# 19  Non Fiction  2017   293736
# 20  Non Fiction  2018   429602
# 21  Non Fiction  2019   424774

# %%
total_reviews_by_genre = amaz.groupby(['Genre', 'Year'])['Reviews'].sum().reset_index()

# Plotting the trend across all years
plt.figure(figsize=(10, 6))
sn.lineplot(x='Year', y='Reviews', hue='Genre', data=total_reviews_by_genre, marker='o')
plt.title('Total Reviews by Genre Across Years')
plt.xlabel('Year')
plt.ylabel('Total Reviews')
plt.show()

# %%
total_review1 = amaz.groupby(['Genre','Year'])['Price'].sum().reset_index()
total_review1
# Out:
#           Genre  Year  Price
# 0       Fiction  2009    374
# 1       Fiction  2010    194
# 2       Fiction  2011    244
# 3       Fiction  2012    258
# 4       Fiction  2013    257
# 5       Fiction  2014    295
# 6       Fiction  2015    159
# 7       Fiction  2016    240
# 8       Fiction  2017    212
# 9       Fiction  2018    184
# 10      Fiction  2019    187
# 11  Non Fiction  2009    396
# 12  Non Fiction  2010    480
# 13  Non Fiction  2011    511
# 14  Non Fiction  2012    507
# 15  Non Fiction  2013    473
# 16  Non Fiction  2014    437
# 17  Non Fiction  2015    362
# 18  Non Fiction  2016    419
# 19  Non Fiction  2017    357
# 20  Non Fiction  2018    342
# 21  Non Fiction  2019    317

# %%
import numpy as np
total_prices_by_genre = amaz.groupby(['Genre', 'Year'])['Price'].sum().reset_index()

# Plotting the trend across all years
plt.figure(figsize=(10, 6))
ax =sn.barplot(x='Year', y='Price', hue='Genre', data=total_prices_by_genre,errwidth=0)
plt.title('Total Prices by Genre Across Years')
plt.xlabel('Year')
plt.ylabel('Total Prices')
#ax.bar_label(ax.containers[0])
plt.show()

# %%
a = amaz['Price'].nsmallest()
a
# Out:
# 42     0
# 71     0
# 116    0
# 193    0
# 219    0
# Name: Price, dtype: int64

# %%
price = amaz['Price']
price
# Out:
# 0       8
# 1      22
# 2      15
# 3       6
# 4      12
#        ..
# 545     8
# 546     8
# 547     8
# 548     8
# 549     8
# Name: Price, Length: 550, dtype: int64

# %%
amaz1 = amaz[['Name','Price']]
amaz1
# Out:
#                                                   Name  Price
# 0                        10-Day Green Smoothie Cleanse      8
# 1                                    11/22/63: A Novel     22
# 2              12 Rules for Life: An Antidote to Chaos     15
# 3                               1984 (Signet Classics)      6
# 4    5,000 Awesome Facts (About Everything!) (Natio...     12
# ..                                                 ...    ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)      8
# 546  You Are a Badass: How to Stop Doubting Your Gr...      8
# 547  You Are a Badass: How to Stop Doubting Your Gr...      8
# 548  You Are a Badass: How to Stop Doubting Your Gr...      8
# 549  You Are a Badass: How to Stop Doubting Your Gr...      8
#
# [550 rows x 2 columns]

# %%
price_less_book= amaz1[amaz1['Price']<5]
price_less_book
# Out:
#                                                   Name  Price
# 8        A Higher Loyalty: Truth, Lies, and Leadership      3
# 11   A Patriot's History of the United States: From...      2
# 15   Adult Coloring Book Designs: Stress Relief Col...      4
# 42          Cabin Fever (Diary of a Wimpy Kid, Book 6)      0
# 43   Calm the F*ck Down: An Irreverent Adult Colori...      4
# 54   Creative Haven Creative Cats Coloring Book (Ad...      4
# 60   Dead And Gone: A Sookie Stackhouse Novel (Sook...      4
# 62   Dead Reckoning (Sookie Stackhouse/True Blood, ...      4
# 71             Diary of a Wimpy Kid: Hard Luck, Book 8      0
# 83   Dog Man: Brawl of the Wild: From the Creator o...      4
# 84   Dog Man: Brawl of the Wild: From the Creator o...      4
# 91   Eat This Not That! Supermarket Survival Guide:...      1
# 103                     Fear: Trump in the White House      2
# 110                                    First 100 Words      4
# ...

# %%
price_less_book.count()
# Out:
# Name     51
# Price    51
# dtype: int64

# %%
amaz.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
az= amaz[['Author','Year']]
az
# Out:
#                        Author  Year
# 0                    JJ Smith  2016
# 1                Stephen King  2011
# 2          Jordan B. Peterson  2018
# 3               George Orwell  2017
# 4    National Geographic Kids  2019
# ..                        ...   ...
# 545               Jeff Kinney  2019
# 546               Jen Sincero  2016
# 547               Jen Sincero  2017
# 548               Jen Sincero  2018
# 549               Jen Sincero  2019
#
# [550 rows x 2 columns]

# %%
az
# Out:
#                        Author  Year
# 0                    JJ Smith  2016
# 1                Stephen King  2011
# 2          Jordan B. Peterson  2018
# 3               George Orwell  2017
# 4    National Geographic Kids  2019
# ..                        ...   ...
# 545               Jeff Kinney  2019
# 546               Jen Sincero  2016
# 547               Jen Sincero  2017
# 548               Jen Sincero  2018
# 549               Jen Sincero  2019
#
# [550 rows x 2 columns]

# %%
year =az['Year']
year
# Out:
# 0      2016
# 1      2011
# 2      2018
# 3      2017
# 4      2019
#        ...
# 545    2019
# 546    2016
# 547    2017
# 548    2018
# 549    2019
# Name: Year, Length: 550, dtype: int64

# %%
g1=amaz[['Name','Author','Year','Reviews',]]
g1
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  Year  Reviews
# 0                    JJ Smith  2016    17350
# 1                Stephen King  2011     2052
# 2          Jordan B. Peterson  2018    18979
# 3               George Orwell  2017    21424
# 4    National Geographic Kids  2019     7665
# ...

# %%
df_2019 = g1[g1['Year'] == 2019]
df_2019
# Out:
#                                                   Name  \
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 33                                            Becoming
# 41            Brown Bear, Brown Bear, What Do You See?
# 44   Can't Hurt Me: Master Your Mind and Defy the Odds
# 74   Difficult Riddles For Smart Kids: 300 Difficul...
# 84   Dog Man: Brawl of the Wild: From the Creator o...
# 85   Dog Man: Fetch-22: From the Creator of Captain...
# 86   Dog Man: For Whom the Ball Rolls: From the Cre...
# 98                                  Educated: A Memoir
# 127                               Giraffes Can't Dance
# 128  Girl, Stop Apologizing: A Shame-Free Plan for ...
# 130  Girl, Wash Your Face: Stop Believing the Lies ...
# 138  Good Days Start With Gratitude: A 52 Week Guid...
# 145                                     Goodnight Moon
# 150                                               Guts
# 155  Harry Potter and the Goblet of Fire: The Illus...
# ...

# %%
df_2019.count()
# Out:
# Name       50
# Author     50
# Year       50
# Reviews    50
# dtype: int64

# %%
total_reviews_by_author = df_2019.groupby('Author')['Reviews'].sum().reset_index()
total_reviews_by_author
# Out:
#                       Author  Reviews
# 0                  Adir Levy     8170
# 1           Alex Michaelides    27536
# 2                  Amy Ramos    13061
# 3                Amy Shields     7866
# 4          Ann Whitford Paul    16643
# 5   Bessel van der Kolk M.D.    12361
# 6            Bill Martin Jr.    14344
# 7                Craig Smith    30183
# 8              Crispin Boyer     5347
# 9                 Dav Pilkey    28943
# 10               Dave Ramsey    11550
# 11             David Goggins    16244
# 12               Delia Owens    87841
# 13             Dinah Bucholz     9030
# 14           Don Miguel Ruiz    23308
# 15                 Dr. Seuss    21834
# 16     Emily Winfield Martin     8842
# 17                Eric Carle    19546
# 18              Gary Chapman    25554
# 19             Giles Andreae    14038
# 20                Harper Lee    26234
# 21           Hopscotch Girls     9737
# 22              Howard Stern     5272
# 23             J. K. Rowling     7758
# ...

# %%
total_reviews_by_author = df_2019.groupby('Author')['Reviews'].sum().nlargest(10).reset_index()
total_reviews_by_author
# Out:
#              Author  Reviews
# 0       Delia Owens    87841
# 1    Michelle Obama    61133
# 2       Craig Smith    30183
# 3     Rachel Hollis    29948
# 4        Dav Pilkey    28943
# 5     Tara Westover    28729
# 6  Alex Michaelides    27536
# 7       Mark Manson    26490
# 8        Harper Lee    26234
# 9      Gary Chapman    25554

# %%
topbest_reviews_book = df_2019.groupby('Name')['Reviews'].sum().reset_index()
topbest_reviews_book
# Out:
#                                                  Name  Reviews
# 0   5,000 Awesome Facts (About Everything!) (Natio...     7665
# 1                                            Becoming    61133
# 2            Brown Bear, Brown Bear, What Do You See?    14344
# 3   Can't Hurt Me: Master Your Mind and Defy the Odds    16244
# 4   Difficult Riddles For Smart Kids: 300 Difficul...     7955
# 5   Dog Man: Brawl of the Wild: From the Creator o...     7235
# 6   Dog Man: Fetch-22: From the Creator of Captain...    12619
# 7   Dog Man: For Whom the Ball Rolls: From the Cre...     9089
# 8                                  Educated: A Memoir    28729
# 9                                Giraffes Can't Dance    14038
# 10  Girl, Stop Apologizing: A Shame-Free Plan for ...     7660
# 11  Girl, Wash Your Face: Stop Believing the Lies ...    22288
# 12  Good Days Start With Gratitude: A 52 Week Guid...    10141
# 13                                     Goodnight Moon     8837
# ...

# %%
len(topbest_reviews_book)
# Out:
# 50

# %%
topbest_reviews_book = df_2019.groupby('Name')['Reviews'].sum().nlargest().reset_index()
topbest_reviews_book
# Out:
#                       Name  Reviews
# 0  Where the Crawdads Sing    87841
# 1                 Becoming    61133
# 2         The Wonky Donkey    30183
# 3       Educated: A Memoir    28729
# 4       The Silent Patient    27536

# %%
# setting the dimensions of the plot
fig, ax = plt.subplots(figsize=(12, 8))
sn.barplot(x, y,ax=ax)
plt.show()
# Out:
# /home/prince/.local/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-351-8367b2089758> in <module>
#       1 # setting the dimensions of the plot
#       2 fig, ax = plt.subplots(figsize=(12, 8))
# ----> 3 sn.barplot(x, y,ax=ax)
#       4 plt.show()
#
# ~/.local/lib/python3.6/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...
